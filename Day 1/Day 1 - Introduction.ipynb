# %% [markdown]
# <a href="">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ![](../logo.png)

# %% [markdown]
# # Makine Öğrenmesi Nedir?
#
# ![main-qimg-cc9dd0bf9677d4010e06c30edfa2def7.png](data:image/png;base64,...)

# %% [markdown]
# ## Makine Öğrenmesi Modeli Aşamaları
#
#
#
# 1.   Makine Öğrenmesi kullanarak evinizin fiyatını tahmin etmek istiyorsunuz. Elinizdeki bu problem Regresyon problemidir.
# 2.   Modelinizi oluşturduktan sonra eğitmek için verilere ihtiyacınız var. Bir evin fiyatını tahmin etmek için hangi bilgilerin olması gerektiğine karar vermeniz gerekiyor.(Örneğin evin metrekaresi, konumu, bina yaşı)
# 3.   Bu bilgileri ve onlara karşılık gelen fiyatı içeren gerçek fiyatların bulunduğu bilgileri Yapay Zeka modelimize veriyoruz. Yapay Zeka modelimiz bu bilgileri öğreniyor.
# 4.   Verdiğimiz bilgileri öğrenen Yapay Zeka modelimize fiyatını öğrenmek istediğimiz evin bilgilerini veriyoruz ve bizim için fiyatı tahmin etmesini istiyoruz.

# %% [markdown]
# ## Makine Öğrenmesi Terminolojisi - 1
#
#
#
# 1.   Feature: Tahmin edilmesini istediğimiz bilgiyi tahmin edebilmesi için modelimize verdiğimiz ve eğitim sırasıda beslediğimiz bilgiler. (Evin metrekaresi, konumu, bina yaşı)
# 2.   Label: Modelimizin gerçekleştirdiği tahmin
# 3.   Target: Evimizin **gerçek** fiyatı

# %% [markdown]
# ## Makine Öğrenmesi Nasıl Çalışır?
#
# ![Untitled design.gif](data:image/gif;base64,...)

# %% [markdown]
# ## Makine Öğrenmesi Terminolojisi - 2
#
#
# 1.   Hiperparametre: Modelimizi eğitirken onun nasıl eğitileceğini belirleyen ve bizim belirlediğimiz değişkenlerdir. Örneğin öğrenme hızı (learning rate)
# 2.   Epoch: Modelimizin eğitim sırasında veriyi baştan sona itere etme sayısıdır
# 3.   Batch Size: Modelimizin eğitimi sırasında verinin hafızaya geliş adedidir.

# %% [markdown]
# ## Makine Öğrenmesi Hangi Alanlarda Kullanılabilir?
#
# *   Mailde spam bulma
# *   Kişiselleştirilmiş Reklamlar
# *   Sağlık Analizi ve Hasta Tedavisi
# *   Sesli Asistanlar
# *   Otonom Araçlar

# %% [markdown]
# ## Problem Çeşitleri

# %% [markdown]
# ### Regresyon
#
# Regresyon bir bağımlı değişken ile diğer birkaç bağımsız değişken arasındaki ilişkiyi belirler. Regresyon analizi, bağımsız değişkenlerin bazıları değiştiğinde bağımlı değişkenin nasıl değiştiğini anlamaya yardımcı olmaktadır.
#
# *   Makine Öğrenmesi Modeli'nin tahmin edeceği değer sürekli bir değerse bu tür bir problem, regresyon problemi kategorisine girer
# *   Lineer Regresyon Kullanılır

# %% [markdown]
# ![Regresyon.png](data:image/png;base64,...)

# %% [markdown]
# ![Regresyon 2.png](data:image/png;base64,...)

# %% [markdown]
# ### Sınıflandırma
#
# *   Makine Öğrenmesi Modeli'nin tahmin edeceği değer kategorik bir değerse bu tür bir problem, sınıflandırma problemi kategorisine girer
# *   Lojistik Regresyon Kullanılır

# %% [markdown]
# ![Classification.png](data:image/png;base64,...)

# %% [markdown]
# # Sci-kit Learn'e Giriş

# %% [markdown]
# ## Sci-kit Learn Nedir?
#
# ***Sci-kit Learn***, Makine Öğrenmesi modelleri oluşturmak ve veriyi önişlemek için kullanılan bir Python kütüphanesidir.

# %% [markdown]
# ## Örnek

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)
reg.score(X, y)

reg.predict(np.array([[3, 5]]))
# Out:
# array([16.])

# %%
reg.coef_
# Out:
# array([1., 2.])

# %%
reg.intercept_
# Out:
# 3.0000000000000018

# %% [markdown]
# # Pandas Revize

# %% [markdown]
# ## Pandas modülünü Import etmek

# %%
import pandas as pd

# %% [markdown]
# ## Csv dosyası okumak

# %%
titanik_df = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv')

# %% [markdown]
# ## DataFrame'i İncelemek

# %%
type(titanik_df)
# Out:
# pandas.core.frame.DataFrame

# %%
titanik_df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanik_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanik_df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
titanik_df.describe().T
# Out:
#              count        mean         std  ...       50%    75%       max
# PassengerId  891.0  446.000000  257.353842  ...  446.0000  668.5  891.0000
# Survived     891.0    0.383838    0.486592  ...    0.0000    1.0    1.0000
# Pclass       891.0    2.308642    0.836071  ...    3.0000    3.0    3.0000
# Age          714.0   29.699118   14.526497  ...   28.0000   38.0   80.0000
# SibSp        891.0    0.523008    1.102743  ...    0.0000    1.0    8.0000
# Parch        891.0    0.381594    0.806057  ...    0.0000    0.0    6.0000
# Fare         891.0   32.204208   49.693429  ...   14.4542   31.0  512.3292
#
# [7 rows x 8 columns]

# %%
titanik_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## DataFrame Elemanlarına Erişmek

# %%
titanik_df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-bad9852f43cc> in <module>()
# ----> 1 titanik_df[0]
#
# ...

# %%
titanik_df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanik_df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanik_df["Age"])
# Out:
# pandas.core.series.Series

# %%
titanik_df[["Age"]]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
type(titanik_df[["Age"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## DataFrame Filtrelemek

# %%
titanik_df[titanik_df.Age > 30]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# 6              7         0       1  ...  51.8625   E46         S
# 11            12         1       1  ...  26.5500  C103         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 873          874         0       3  ...   9.0000   NaN         S
# 879          880         1       1  ...  83.1583   C50         C
# 881          882         0       3  ...   7.8958   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [305 rows x 12 columns]

# %% [markdown]
# ## Eksik Veriler

# %%
titanik_df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
titanik_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanik_df[titanik_df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 5              6         0       3  ...   8.4583   NaN         Q
# 17            18         1       2  ...  13.0000   NaN         S
# 19            20         1       3  ...   7.2250   NaN         C
# 26            27         0       3  ...   7.2250   NaN         C
# 28            29         1       3  ...   7.8792   NaN         Q
# ..           ...       ...     ...  ...      ...   ...       ...
# 859          860         0       3  ...   7.2292   NaN         C
# 863          864         0       3  ...  69.5500   NaN         S
# 868          869         0       3  ...   9.5000   NaN         S
# 878          879         0       3  ...   7.8958   NaN         S
# 888          889         0       3  ...  23.4500   NaN         S
#
# [177 rows x 12 columns]

# %%
titanik_df.fillna('mean')
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin Embarked
# 0              1         0       3  ...   7.2500  mean        S
# 1              2         1       1  ...  71.2833   C85        C
# 2              3         1       3  ...   7.9250  mean        S
# 3              4         1       1  ...  53.1000  C123        S
# 4              5         0       3  ...   8.0500  mean        S
# ..           ...       ...     ...  ...      ...   ...      ...
# 886          887         0       2  ...  13.0000  mean        S
# 887          888         1       1  ...  30.0000   B42        S
# 888          889         0       3  ...  23.4500  mean        S
# 889          890         1       1  ...  30.0000  C148        C
# 890          891         0       3  ...   7.7500  mean        Q
#
# [891 rows x 12 columns]
